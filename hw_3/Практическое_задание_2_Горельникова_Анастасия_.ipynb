# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Считайте датасет

# %%
df = pd.read_csv('/train.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Выведите основную информацию о датасете

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# смотрим пропуски
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Посчитайте процент выживаемости у каждого класса пассажиров (Pclass)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
Share_survived = (df.groupby('Pclass')['Survived'].mean()*100).round(2)
Share_survived
# Out:
# Pclass
# 1    62.96
# 2    47.28
# 3    24.24
# Name: Survived, dtype: float64

# %% [markdown]
# Выведите самое популярное мужское и самое популярное женское имя на корабл

# %%
# смотрим, как указаны имена
df['Name'].sample(n=10)
# Out:
# 549    Davies, Master. John Morgan Jr
# 828      McCormack, Mr. Thomas Joseph
# 881                Markun, Mr. Johann
# 857            Daly, Mr. Peter Denis
# 677           Turja, Miss. Anna Sofia
# 365    Adahl, Mr. Mauritz Nils Martin
# 724     Chambers, Mr. Norman Campbell
# 292            Levy, Mr. Rene Jacques
# 616         Danbom, Mr. Ernst Gilbert
# 602         Harrington, Mr. Charles H
# Name: Name, dtype: object

# %%
df['name_new'] = df['Name'].str.split(',').str[0]

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked name_new
# 0      0  A/5 21171  7.25   NaN        S   Braund

# %%
name_grouped = df.groupby('Sex')['name_new'].value_counts(ascending=False)
name_grouped = name_grouped.groupby('Sex').head(1)
name_grouped
# Out:
# Sex     name_new
# female  Andersson    6
# male    Panula       5
# Name: count, dtype: int64

# %% [markdown]
# Выведите самое популярное мужское и самое популярное женское имя на корабле в каждом классе

# %%
name_grouped_Pclass = df.groupby(['Sex', 'Pclass'])['name_new'].value_counts(ascending=False)
name_grouped_Pclass = name_grouped_Pclass.groupby(['Sex', 'Pclass']).head(1)
name_grouped_Pclass
# Out:
# Sex     Pclass  name_new
# female  1       Allison      2
#         2       Brown        2
#         3       Andersson    6
# male    1       Carter       2
#         2       Hickman      3
#         3       Panula       5
# Name: count, dtype: int64

# %% [markdown]
# Выведите часть таблицы с пассажирами, возраст которых больше 44 лет

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked name_new
# 0      0  A/5 21171   7.2500   NaN        S   Braund
# 1      0   PC 17599  71.2833   C85        C  Cumings

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
# т.к. в задании не указано, что строго больше 44 лет, я поставила больше или равно 44
df_ages_more_44 = df[df['Age']>=44].sort_values('Age')
df_ages_more_44
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 194          195         1       1  Brown, Mrs. James Joseph (Margaret Tobin)
# 236          237         0       2                          Hold, Mr. Stephen
# 245          246         0       1                Minahan, Dr. William Edward
# 160          161         0       3                   Cribb, Mr. John Hatfield
# 414          415         1       3                  Sundman, Mr. Johan Julian
# ..           ...       ...     ...                                        ...
# 116          117         0       3                       Connors, Mr. Patrick
# 96            97         0       1                  Goldschmidt, Mr. George B
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 851          852         0       3                        Svensson, Mr. Johan
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
#
# ...

# %% [markdown]
# Выведите часть таблицы с пассажирами, возраст которых меньше 44 лет и которые мужского пола

# %%
df_less_44_men = df[(df['Age']<44) & (df['Sex']=='male')]
df_less_44_men
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked     name_new
# ...

# %% [markdown]
# Выведите количества n-местных кабин (в которых было 2, 3, 4, ... человека)

# %%
df['Cabin'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Cabin
# Non-Null Count  Dtype
# --------------  -----
# 204 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
df['Cabin'].isna().value_counts()
# Out:
# Cabin
# True     687
# False    204
# Name: count, dtype: int64

# %%
df2 = df[df['Cabin'].notna()]

# %%
df2['Cabin'].isna().value_counts()
# Out:
# Cabin
# False    204
# Name: count, dtype: int64

# %%
df2.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin Embarked  name_new
# 1      0  PC 17599  71.2833   C85        C   Cumings
# 3      0    113803  53.1000  C123        S  Futrelle

# %%
cabin_seats = df2.groupby('Cabin').size()
cabin_seats
# Out:
# Cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Length: 147, dtype: int64

# %%
cabin_count = cabin_seats.value_counts().sort_index()
cabin_count
# Out:
# 1    101
# 2     38
# 3      5
# 4      3
# Name: count, dtype: int64
